# %%
# !pip install torchmetrics clearml
# !pip install hydra-core==1.3.2 omegaconf==2.3.0 -q
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=XGMS61QRIXH7G4URU0X7VGTDAIQUVE
# %env CLEARML_API_SECRET_KEY=3mpOB_Br37BLBntBoUvtxmfbBfmkbkdfRUYGje8GfL1gwe_ufJd1w4UzuQWOPaAtTWE

import sys
import os
from google.colab import drive

drive.mount('/content/drive',force_remount=True)
project_path = '/content/drive/MyDrive/segmentation_project'
sys.path.append(project_path)
import kagglehub
path = kagglehub.dataset_download("zaryabahmadkhan/2d-slicing-of-imagetbad-dataset")
print(f"{path}")

from modules.config import load_config as config
from modules.data import split, Dataset, transformers
from modules.model import UNet
from modules.train import train_epoch, validate_epoch, early_stopping, train_model
from modules.utils import settings

cfg = config()
print('eh')
if __name__ == '__main__':
    train_model()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.11.0
#     Uninstalling PyJWT-2.11.0:
#       Successfully uninstalled PyJWT-2.11.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 4.4 MB/s eta 0:00:00
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=XGMS61QRIXH7G4URU0X7VGTDAIQUVE
# env: CLEARML_API_SECRET_KEY=3mpOB_Br37BLBntBoUvtxmfbBfmkbkdfRUYGje8GfL1gwe_ufJd1w4UzuQWOPaAtTWE
# Mounted at /content/drive
# ...
# 100%|██████████| 2.42G/2.42G [00:31<00:00, 82.4MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/zaryabahmadkhan/2d-slicing-of-imagetbad-dataset/versions/1
# eh
# ClearML Task: created new task id=fa070e80058a4b90a28ffae11f0d890d
# ...
